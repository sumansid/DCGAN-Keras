# %%
import tensorflow as tf
from numpy import savez_compressed, load
from os import listdir
from mtcnn.mtcnn import MTCNN
from keras.models import load_model
from tensorflow import keras
import matplotlib.pyplot as plt
from PIL import Image 
import numpy as np
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import *
from keras.optimizers import *
from numpy.random import randn
from numpy.random import randint
from numpy import zeros
from numpy.random import random
from numpy import vstack
import numpy as np
from numpy.random import rand 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def load_faces(directory, n_faces):
  model = MTCNN()
  faces = list()
  for file_name in listdir(directory):
    img = Image.open(directory + str("/")+ file_name)
    img = img.convert('RGB')
    pixels = np.asarray(img)
    face = get_face(model,pixels)
    if face is None :
      continue
    faces.append(face)
    if len(faces) >= n_faces:
      break
  return np.asarray(faces)

# %%
def plot_faces(faces,n_faces):
  for i in range(n_faces * n_faces):
    plt.subplot(n_faces,n_faces,i+1)
    plt.axis("off")
    plt.imshow(faces[i])
  plt.show()

# %%
directory = "/content/drive/My Drive/celeb_images"
faces = load_faces(directory,300)
savez_compressed("celeb_faces_only.npz", faces)
plot_faces(faces,5)

# %%
#!pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading https://files.pythonhosted.org/packages/67/43/abee91792797c609c1bf30f1112117f7a87a713ebaa6ec5201d5555a73ef/mtcnn-0.1.0-py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 8.2MB/s
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from mtcnn) (4.1.2.30)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from mtcnn) (2.3.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (1.12.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (1.1.2)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.0

# %%
# Extracting only the faces from the celeb faces dataset
def get_face(model,pixels,output_size=(80,80)):
  faces = model.detect_faces(pixels)
  if len(faces) == 0 :
    return None
  x1,y1,width,height = faces[0]['box']
  x1,y1 = abs(x1), abs(y1)
  x2,y2 = x1 + width , y1 + height
  face_pixels = pixels[y1:y2,x1:x2]
  img = Image.fromarray(face_pixels)
  img = img.resize(output_size)
  face_array = np.asarray(img)
  return face_array

# %%
def discriminator_model(input_shape=(80,80,3)):
  model = Sequential()
  model.add(Conv2D(128,(5,5),padding="same",input_shape = input_shape))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(128,(5,5),strides = (2,2),padding="same"))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(128,(5,5),strides = (2,2),padding="same"))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(128,(5,5),strides = (2,2),padding="same"))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(128,(5,5),strides = (2,2),padding="same"))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Flatten()) 
  model.add(Dropout(0.4))
  model.add(Dense(1, activation="sigmoid"))
  optimizer = Adam(learning_rate=0.0002, beta_1 = 0.5)
  model.compile(loss="binary_crossentropy",optimizer=optimizer,metrics=["accuracy"])
  return model

# %%
def generator_model(latent_dim):
  model = Sequential()
  n_nodes = 128 * 5 * 5
  model.add(Dense(n_nodes,input_dim = latent_dim))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Reshape((5,5,128)))
  model.add(Conv2DTranspose(128,(4,4), strides=(2,2),padding="same"))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2DTranspose(128,(4,4), strides=(2,2),padding="same"))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2DTranspose(128,(4,4), strides=(2,2),padding="same"))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2DTranspose(128,(4,4), strides=(2,2),padding="same"))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(3,(5,5),activation="tanh",padding="same"))
  return model

# %%
def gan_model(generator, discriminator):
  model = Sequential()
  discriminator.trainable = False
  model.add(generator)
  model.add(discriminator)
  optimizer = Adam(learning_rate=0.0002, beta_1 = 0.5)
  model.compile(loss="binary_crossentropy", optimizer=optimizer)
  return model

# %%
# Load and scale the real samples
def load_real_faces():
  face_data = load("celeb_faces_only.npz")
  faces = face_data["arr_0"]
  X = faces.astype("float32")
  X = (X-127.5) / 127.5
  return X

# %%
def select_real_samples(dataset, n_samples):
  idx = randint(0,dataset.shape[0],n_samples)
  X = dataset[idx]
  y = np.ones((n_samples,1))
  return X,y

# %%
def generate_latent_points(latent_dim, n_samples):
  inp = randn(latent_dim * n_samples)
  X = inp.reshape(n_samples,latent_dim)
  return X

# %%
def generate_fake_samples(generator,latent_dim, n_samples):
  x_input = generate_latent_points(latent_dim,n_samples)
  x_output = generator.predict(x_input)
  y = np.zeros((n_samples,1))
  return x_output,y

# %%
def train_gan(generator, discriminator, gan_model,dataset, latent_dim,n_epochs=100,n_batches=25):
  batches_per_epoch = int(dataset.shape[0] / n_batches)
  half_batch = int(n_batches / 2)
  for i in range(n_epochs):
    for j in range(batches_per_epoch):
      x_real,y_real = select_real_samples(dataset, half_batch)
      d_loss1, _ = discriminator.train_on_batch(x_real, y_real)
      x_fake,y_fake = generate_fake_samples(generator,latent_dim, half_batch)
      d_loss2, _ = discriminator.train_on_batch(x_fake, y_fake)
      x_gan = generate_latent_points(latent_dim,n_batches)
      y_gan = np.ones((n_batches,1))
      g_loss = gan_model.train_on_batch(x_gan,y_gan)
      print("Epoch " + str(i) + " Batch " + str(j) + " Loss on real "+ str(d_loss1)+ " loss on fake " + str(d_loss2)+ " generator loss " + str(g_loss))
    if (i + 1) % 5 == 0 :
      summarize_model_performance(i, generator, discriminator, dataset, latent_dim)

# %%
def summarize_model_performance(i, generator, discriminator, dataset, latent_dim, n_samples=50):
  x_real, y_real = select_real_samples(dataset,n_samples)
  _, acc_real = discriminator.evaluate(x_real, y_real, verbose=0)
  x_fake, y_fake = generate_fake_sampels(generator,latent_dim, n_samples)
  _, acc_fake = discriminator.evaluate(x_fake, y_fake, verbose = 0)
  print("Accuracy on real " + str(acc_real) + " Accuracy on fake " + str(acc_fake))
  x_fake = (x_fake + 1) / 2.0
  for k in range(5*5):
    plt.subplot(5,5,1+k)
    plt.axis("off")
    plt.imshow(x_fake[k])
  image_name = "generated_plot_e%03d.png" % (i+1)
  plt.savefig(image_name)
  plt.close()
  model_name = "generated_model_e%03d.h5" % (i+1)
  generator.save(model_name)

# %%
latent_dim = 100
discriminator = discriminator_model()
generator = generator_model(latent_dim)
gan = gan_model(generator, discriminator)
dataset = load_real_faces()
train_gan(generator, discriminator, gan,dataset, latent_dim,n_epochs=100,n_batches=25)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch 0 Batch 0 Loss on real 0.69690853 loss on fake 0.6956713 generator loss 0.6923073
# Epoch 0 Batch 1 Loss on real 0.55547667 loss on fake 0.6963971 generator loss 0.6920403
# Epoch 0 Batch 2 Loss on real 0.2090139 loss on fake 0.7009013 generator loss 0.69208664
# Epoch 0 Batch 3 Loss on real 0.0141544165 loss on fake 0.71288687 generator loss 0.69339544
# Epoch 0 Batch 4 Loss on real 0.0005873278 loss on fake 0.7175715 generator loss 0.6953402
# Epoch 0 Batch 5 Loss on real 0.0020758484 loss on fake 0.71153075 generator loss 0.7010528
# Epoch 0 Batch 6 Loss on real 0.0075167133 loss on fake 0.6905739 generator loss 0.71095586
# Epoch 0 Batch 7 Loss on real 0.0054901987 loss on fake 0.6895248 generator loss 0.7344629
# Epoch 0 Batch 8 Loss on real 0.012541443 loss on fake 0.6585028 generator loss 0.7707331
# Epoch 0 Batch 9 Loss on real 0.0064904913 loss on fake 0.6354178 generator loss 0.8295317
# Epoch 0 Batch 10 Loss on real 0.020640282 loss on fake 0.5966229 generator loss 0.91545075
# Epoch 0 Batch 11 Loss on real 0.000345604 loss on fake 0.50407535 generator loss 1.203604
# Epoch 1 Batch 0 Loss on real 0.01594813 loss on fake 0.3800038 generator loss 1.5696766
# Epoch 1 Batch 1 Loss on real 1.8269979e-10 loss on fake 0.18214457 generator loss 2.7798374
# Epoch 1 Batch 2 Loss on real 8.9574745e-12 loss on fake 0.041757017 generator loss 4.371828
# Epoch 1 Batch 3 Loss on real 1.1219718e-12 loss on fake 0.011892454 generator loss 5.54286
# Epoch 1 Batch 4 Loss on real 2.2846313e-14 loss on fake 0.042267304 generator loss 7.6092405
# Epoch 1 Batch 5 Loss on real 2.0541638e-16 loss on fake 0.025413679 generator loss 17.017145
# Epoch 1 Batch 6 Loss on real 1.13399224e-17 loss on fake 4.8292224e-09 generator loss 23.454502
# Epoch 1 Batch 7 Loss on real 5.7045174 loss on fake 0.0001370797 generator loss 5.3953133
# Epoch 1 Batch 8 Loss on real 9.707852e-25 loss on fake 0.036744956 generator loss 2.9017608
# Epoch 1 Batch 9 Loss on real 1.4868261e-36 loss on fake 4.4366984 generator loss 2.0431397
# Epoch 1 Batch 10 Loss on real 8.788029e-16 loss on fake 1.4859327 generator loss 0.93824553
# Epoch 1 Batch 11 Loss on real 5.676765e-07 loss on fake 0.8178466 generator loss 0.7452161
# Epoch 2 Batch 0 Loss on real 0.002718893 loss on fake 0.67145425 generator loss 0.7926413
# Epoch 2 Batch 1 Loss on real 0.07510215 loss on fake 0.63773775 generator loss 0.8019731
# Epoch 2 Batch 2 Loss on real 0.00045791097 loss on fake 0.57486874 generator loss 1.034294
# Epoch 2 Batch 3 Loss on real 0.0063112844 loss on fake 0.38420692 generator loss 1.7806233
# Epoch 2 Batch 4 Loss on real 0.2510037 loss on fake 0.43167877 generator loss 1.1823077
# Epoch 2 Batch 5 Loss on real 7.4850014e-08 loss on fake 0.36037192 generator loss 1.9041991
# Epoch 2 Batch 6 Loss on real 2.6406533e-06 loss on fake 0.13957816 generator loss 2.9661462
# Epoch 2 Batch 7 Loss on real 0.0024840601 loss on fake 0.070098154 generator loss 3.7114418
# Epoch 2 Batch 8 Loss on real 0.0004991432 loss on fake 0.053660404 generator loss 3.8051484
# Epoch 2 Batch 9 Loss on real 0.006979628 loss on fake 0.09706255 generator loss 4.3000426
# Epoch 2 Batch 10 Loss on real 5.17672e-05 loss on fake 0.03202618 generator loss 4.586894
# Epoch 2 Batch 11 Loss on real 1.041661 loss on fake 1.0522642 generator loss 2.256212
# Epoch 3 Batch 0 Loss on real 8.151128e-08 loss on fake 0.51333 generator loss 3.1687324
# Epoch 3 Batch 1 Loss on real 0.00042054986 loss on fake 0.12945794 generator loss 4.774895
# Epoch 3 Batch 2 Loss on real 0.040384922 loss on fake 0.025709048 generator loss 5.0299444
# Epoch 3 Batch 3 Loss on real 0.016167538 loss on fake 0.038715344 generator loss 4.343973
# Epoch 3 Batch 4 Loss on real 0.0030500612 loss on fake 0.044850335 generator loss 5.9672065
# Epoch 3 Batch 5 Loss on real 3.7920614e-05 loss on fake 0.006828798 generator loss 6.2201
# Epoch 3 Batch 6 Loss on real 0.002723262 loss on fake 0.020349687 generator loss 4.8853874
# Epoch 3 Batch 7 Loss on real 0.008125897 loss on fake 0.03854673 generator loss 4.306302
# Epoch 3 Batch 8 Loss on real 0.7150962 loss on fake 0.2847083 generator loss 5.800969
# Epoch 3 Batch 9 Loss on real 6.039905e-11 loss on fake 0.08762922 generator loss 13.344307
# Epoch 3 Batch 10 Loss on real 5.18215e-06 loss on fake 1.274026e-06 generator loss 17.443092
# Epoch 3 Batch 11 Loss on real 0.0017870573 loss on fake 1.1854056e-06 generator loss 14.285923
# Epoch 4 Batch 0 Loss on real 0.00079626037 loss on fake 3.4922243e-05 generator loss 10.596807
# Epoch 4 Batch 1 Loss on real 8.1346916e-05 loss on fake 0.0014534475 generator loss 7.0762343
# Epoch 4 Batch 2 Loss on real 0.024990821 loss on fake 1.3473768 generator loss 22.893692
# Epoch 4 Batch 3 Loss on real 0.597598 loss on fake 1.0743526e-07 generator loss 17.241653
# Epoch 4 Batch 4 Loss on real 0.57339466 loss on fake 0.00014514377 generator loss 8.172418
# Epoch 4 Batch 5 Loss on real 0.42236447 loss on fake 0.0115509005 generator loss 4.0105324
# Epoch 4 Batch 6 Loss on real 3.9205098e-21 loss on fake 0.045009945 generator loss 3.0767705
# Epoch 4 Batch 7 Loss on real 6.225954e-08 loss on fake 0.09228025 generator loss 3.0164564
# Epoch 4 Batch 8 Loss on real 3.5709177e-10 loss on fake 0.20259905 generator loss 3.506051
# Epoch 4 Batch 9 Loss on real 0.01031074 loss on fake 0.41246474 generator loss 6.2337327
# Epoch 4 Batch 10 Loss on real 0.0 loss on fake 0.0042443047 generator loss 7.3442397
# Epoch 4 Batch 11 Loss on real 5.699463e-26 loss on fake 0.42152783 generator loss 10.119633
# Accuracy on real 0.9399999976158142 Accuracy on fake 0.1599999964237213
# Epoch 5 Batch 0 Loss on real 2.3548956 loss on fake 0.09249461 generator loss 5.0554137
# Epoch 5 Batch 1 Loss on real 0.018231431 loss on fake 0.018344857 generator loss 5.154796
# Epoch 5 Batch 2 Loss on real 5.162004e-07 loss on fake 0.0936309 generator loss 8.3168125
# Epoch 5 Batch 3 Loss on real 3.0707877e-06 loss on fake 0.00058018736 generator loss 8.733995
# Epoch 5 Batch 4 Loss on real 1.2035943 loss on fake 0.91026664 generator loss 1.4077699
# Epoch 5 Batch 5 Loss on real 2.2763474e-07 loss on fake 0.3220543 generator loss 1.761148
# Epoch 5 Batch 6 Loss on real 3.1345935e-06 loss on fake 0.20985842 generator loss 2.1164176
# Epoch 5 Batch 7 Loss on real 1.415033e-12 loss on fake 0.4821914 generator loss 2.8959491
# Epoch 5 Batch 8 Loss on real 9.983434e-05 loss on fake 0.08305866 generator loss 3.5386524
# Epoch 5 Batch 9 Loss on real 6.75237e-10 loss on fake 1.0743344 generator loss 6.8402514
# Epoch 5 Batch 10 Loss on real 2.129934e-06 loss on fake 0.0006856399 generator loss 9.029519
# Epoch 5 Batch 11 Loss on real 0.04696114 loss on fake 0.0006767181 generator loss 8.782493
# Epoch 6 Batch 0 Loss on real 0.67116785 loss on fake 0.01243689 generator loss 3.556916
# Epoch 6 Batch 1 Loss on real 5.8362207e-06 loss on fake 0.3980585 generator loss 2.36151
# Epoch 6 Batch 2 Loss on real 0.1421854 loss on fake 3.7930956 generator loss 2.1592588
# Epoch 6 Batch 3 Loss on real 0.09481173 loss on fake 0.26545233 generator loss 3.3872964
# Epoch 6 Batch 4 Loss on real 3.3840122 loss on fake 0.0056319493 generator loss 8.69531
# Epoch 6 Batch 5 Loss on real 4.478127 loss on fake 0.77959996 generator loss 1.0290524
# Epoch 6 Batch 6 Loss on real 0.3375055 loss on fake 0.402431 generator loss 1.3934503
# Epoch 6 Batch 7 Loss on real 0.20180672 loss on fake 0.25749353 generator loss 1.6175635
# Epoch 6 Batch 8 Loss on real 0.039699037 loss on fake 0.19804423 generator loss 1.8893216
# Epoch 6 Batch 9 Loss on real 0.0048549497 loss on fake 0.1804287 generator loss 1.9954089
# Epoch 6 Batch 10 Loss on real 0.004115878 loss on fake 0.16499984 generator loss 2.1403732
# Epoch 6 Batch 11 Loss on real 0.00893267 loss on fake 0.17091733 generator loss 1.9595442
# Epoch 7 Batch 0 Loss on real 0.004106818 loss on fake 0.18619645 generator loss 2.2094903
# Epoch 7 Batch 1 Loss on real 0.004642255 loss on fake 0.16470368 generator loss 2.20399
# Epoch 7 Batch 2 Loss on real 0.038210128 loss on fake 0.107775085 generator loss 2.4773536
# Epoch 7 Batch 3 Loss on real 0.070830084 loss on fake 0.09754031 generator loss 2.7327857
# Epoch 7 Batch 4 Loss on real 0.00026635503 loss on fake 0.08292857 generator loss 2.8876517
# Epoch 7 Batch 5 Loss on real 0.00021015399 loss on fake 0.080441974 generator loss 3.1926072
# Epoch 7 Batch 6 Loss on real 0.00022394214 loss on fake 0.046054453 generator loss 3.5545733
# Epoch 7 Batch 7 Loss on real 0.0029995383 loss on fake 0.05128138 generator loss 3.9829218
# Epoch 7 Batch 8 Loss on real 0.00034262947 loss on fake 0.03363061 generator loss 4.401806
# Epoch 7 Batch 9 Loss on real 0.0036038272 loss on fake 0.027959367 generator loss 4.4330735
# Epoch 7 Batch 10 Loss on real 0.0055172965 loss on fake 0.024744593 generator loss 4.4494705
# Epoch 7 Batch 11 Loss on real 0.0019838107 loss on fake 0.03343484 generator loss 4.601648
# Epoch 8 Batch 0 Loss on real 0.0034191597 loss on fake 0.046049815 generator loss 4.3495965
# Epoch 8 Batch 1 Loss on real 0.00042151185 loss on fake 0.09532088 generator loss 3.6144783
# Epoch 8 Batch 2 Loss on real 0.0038115073 loss on fake 0.783912 generator loss 4.75497
# Epoch 8 Batch 3 Loss on real 0.00034978674 loss on fake 0.08360994 generator loss 3.927705
# Epoch 8 Batch 4 Loss on real 0.034538455 loss on fake 0.25189674 generator loss 2.2435627
# Epoch 8 Batch 5 Loss on real 0.03943685 loss on fake 0.48752475 generator loss 2.5878315
# Epoch 8 Batch 6 Loss on real 0.122861445 loss on fake 0.12252525 generator loss 3.6133447
# Epoch 8 Batch 7 Loss on real 0.18440099 loss on fake 0.15530483 generator loss 2.9755878
# Epoch 8 Batch 8 Loss on real 0.10963709 loss on fake 0.5288181 generator loss 4.2223406
# Epoch 8 Batch 9 Loss on real 0.086843885 loss on fake 0.008998082 generator loss 5.9630337
# Epoch 8 Batch 10 Loss on real 0.026520045 loss on fake 0.009254106 generator loss 5.0658216
# Epoch 8 Batch 11 Loss on real 0.468642 loss on fake 0.32442075 generator loss 3.70299
# Epoch 9 Batch 0 Loss on real 0.008994111 loss on fake 0.086476475 generator loss 4.827831
# Epoch 9 Batch 1 Loss on real 0.21824564 loss on fake 0.088287495 generator loss 3.7056794
# Epoch 9 Batch 2 Loss on real 0.00049484876 loss on fake 0.26094475 generator loss 7.8130164
# Epoch 9 Batch 3 Loss on real 0.85875016 loss on fake 0.004134727 generator loss 5.6456776
# Epoch 9 Batch 4 Loss on real 0.021276725 loss on fake 0.013575487 generator loss 4.810709
# Epoch 9 Batch 5 Loss on real 0.101086445 loss on fake 0.13950135 generator loss 5.6495457
# Epoch 9 Batch 6 Loss on real 0.006267306 loss on fake 0.0045604445 generator loss 6.365694
# Epoch 9 Batch 7 Loss on real 0.0019158811 loss on fake 0.004996035 generator loss 5.625575
# Epoch 9 Batch 8 Loss on real 0.5995907 loss on fake 0.78936595 generator loss 4.1834846
# Epoch 9 Batch 9 Loss on real 1.074291 loss on fake 0.58751637 generator loss 1.0412183
# Epoch 9 Batch 10 Loss on real 0.0019321408 loss on fake 0.5557851 generator loss 3.2596366
# Epoch 9 Batch 11 Loss on real 0.03329784 loss on fake 0.17830932 generator loss 3.2294564
# Accuracy on real 0.9399999976158142 Accuracy on fake 1.0
# Epoch 10 Batch 0 Loss on real 0.008375662 loss on fake 0.07930814 generator loss 2.8112655
# Epoch 10 Batch 1 Loss on real 0.55857855 loss on fake 0.088041864 generator loss 3.3481703
# Epoch 10 Batch 2 Loss on real 0.021461552 loss on fake 0.07949593 generator loss 3.8567998
# Epoch 10 Batch 3 Loss on real 0.078258075 loss on fake 0.07200698 generator loss 4.072573
# Epoch 10 Batch 4 Loss on real 0.16965972 loss on fake 0.3718727 generator loss 6.956813
# Epoch 10 Batch 5 Loss on real 0.17311333 loss on fake 0.0014130803 generator loss 6.863551
# Epoch 10 Batch 6 Loss on real 0.37999186 loss on fake 0.020006686 generator loss 3.3441737
# Epoch 10 Batch 7 Loss on real 0.00082617014 loss on fake 0.32506517 generator loss 4.8248296
# Epoch 10 Batch 8 Loss on real 0.074001916 loss on fake 0.009877597 generator loss 5.743131
# Epoch 10 Batch 9 Loss on real 0.37739158 loss on fake 0.39191756 generator loss 4.132725
# Epoch 10 Batch 10 Loss on real 0.05647641 loss on fake 0.016173147 generator loss 4.686989
# Epoch 10 Batch 11 Loss on real 0.027086908 loss on fake 0.026876325 generator loss 4.5030503
# Epoch 11 Batch 0 Loss on real 0.0110288 loss on fake 0.040039923 generator loss 4.1187396
# Epoch 11 Batch 1 Loss on real 0.00024409026 loss on fake 0.02039817 generator loss 4.452381
# Epoch 11 Batch 2 Loss on real 0.0017981236 loss on fake 0.053951535 generator loss 4.064226
# Epoch 11 Batch 3 Loss on real 0.008859557 loss on fake 0.25126973 generator loss 3.7529325
# Epoch 11 Batch 4 Loss on real 0.022045514 loss on fake 0.015920822 generator loss 6.68398
# Epoch 11 Batch 5 Loss on real 0.07651914 loss on fake 0.0133979395 generator loss 4.8449802
# Epoch 11 Batch 6 Loss on real 0.4834548 loss on fake 0.030383056 generator loss 3.7690458
# Epoch 11 Batch 7 Loss on real 0.00017641718 loss on fake 0.03738477 generator loss 3.9738376
# Epoch 11 Batch 8 Loss on real 0.00065192446 loss on fake 0.04502989 generator loss 4.5623045
# Epoch 11 Batch 9 Loss on real 0.0014914385 loss on fake 0.05427332 generator loss 4.5229626
# Epoch 11 Batch 10 Loss on real 0.37841785 loss on fake 0.16657466 generator loss 3.84539
# Epoch 11 Batch 11 Loss on real 4.6641394e-06 loss on fake 0.027376944 generator loss 4.517104
# Epoch 12 Batch 0 Loss on real 0.00013782344 loss on fake 0.013422042 generator loss 4.5904956
# Epoch 12 Batch 1 Loss on real 0.0018162443 loss on fake 0.014913914 generator loss 4.163212
# Epoch 12 Batch 2 Loss on real 0.037953805 loss on fake 0.025241872 generator loss 4.1213317
# Epoch 12 Batch 3 Loss on real 0.035989743 loss on fake 0.066222906 generator loss 4.4298735
# Epoch 12 Batch 4 Loss on real 0.0057338825 loss on fake 0.014080629 generator loss 4.658024
# Epoch 12 Batch 5 Loss on real 0.0970794 loss on fake 0.14465584 generator loss 4.608821
# Epoch 12 Batch 6 Loss on real 0.0013701349 loss on fake 0.022513585 generator loss 5.113045
# Epoch 12 Batch 7 Loss on real 0.0009877495 loss on fake 0.019274494 generator loss 4.1800456
# Epoch 12 Batch 8 Loss on real 0.35421717 loss on fake 0.62968975 generator loss 7.684523
# Epoch 12 Batch 9 Loss on real 0.10058111 loss on fake 0.042621862 generator loss 5.8471813
# Epoch 12 Batch 10 Loss on real 0.33416453 loss on fake 5.9809265 generator loss 8.701779
# Epoch 12 Batch 11 Loss on real 0.31162706 loss on fake 0.00011027026 generator loss 9.098482
# Epoch 13 Batch 0 Loss on real 1.8473424 loss on fake 0.05158029 generator loss 2.2663128
# Epoch 13 Batch 1 Loss on real 0.02446636 loss on fake 0.17311853 generator loss 2.6118314
# Epoch 13 Batch 2 Loss on real 0.0065012737 loss on fake 0.06454057 generator loss 3.313867
# Epoch 13 Batch 3 Loss on real 0.14738281 loss on fake 0.05429418 generator loss 3.5460758
# Epoch 13 Batch 4 Loss on real 0.06827497 loss on fake 0.040329706 generator loss 3.7889597
# Epoch 13 Batch 5 Loss on real 0.09460816 loss on fake 0.02804483 generator loss 3.7609766
# Epoch 13 Batch 6 Loss on real 0.0088119125 loss on fake 0.02577281 generator loss 3.8953826
# Epoch 13 Batch 7 Loss on real 0.3875369 loss on fake 0.048425168 generator loss 3.491688
# Epoch 13 Batch 8 Loss on real 0.014737711 loss on fake 0.04681909 generator loss 3.582315
# Epoch 13 Batch 9 Loss on real 0.0246322 loss on fake 0.048036773 generator loss 4.0770645
# Epoch 13 Batch 10 Loss on real 4.583899e-06 loss on fake 0.031851504 generator loss 4.4925656
# Epoch 13 Batch 11 Loss on real 0.024107506 loss on fake 0.03426404 generator loss 4.375009
# Epoch 14 Batch 0 Loss on real 4.658687e-06 loss on fake 0.038413227 generator loss 4.604617
# Epoch 14 Batch 1 Loss on real 0.039072193 loss on fake 0.043134835 generator loss 4.6625586
# Epoch 14 Batch 2 Loss on real 0.05596219 loss on fake 0.040441904 generator loss 6.081951
# Epoch 14 Batch 3 Loss on real 0.0025825084 loss on fake 0.0035021715 generator loss 6.113639
# Epoch 14 Batch 4 Loss on real 0.33737502 loss on fake 0.044258013 generator loss 4.5136776
# Epoch 14 Batch 5 Loss on real 0.03738216 loss on fake 0.061641145 generator loss 6.1212244
# Epoch 14 Batch 6 Loss on real 0.019350205 loss on fake 0.017974827 generator loss 5.553083
# Epoch 14 Batch 7 Loss on real 0.084053926 loss on fake 0.09414587 generator loss 4.6194673
# Epoch 14 Batch 8 Loss on real 0.005935848 loss on fake 0.105578415 generator loss 4.2628236
# Epoch 14 Batch 9 Loss on real 0.76388484 loss on fake 0.41010723 generator loss 2.514253
# Epoch 14 Batch 10 Loss on real 0.0008228719 loss on fake 0.08764336 generator loss 3.3872604
# Epoch 14 Batch 11 Loss on real 0.09876711 loss on fake 0.056969736 generator loss 3.4847412
# Accuracy on real 0.9599999785423279 Accuracy on fake 1.0
# Epoch 15 Batch 0 Loss on real 0.01761525 loss on fake 0.06314656 generator loss 3.7563226
# Epoch 15 Batch 1 Loss on real 0.1716343 loss on fake 0.064713396 generator loss 3.4777732
# Epoch 15 Batch 2 Loss on real 0.0126503 loss on fake 0.079642996 generator loss 3.5028176
# Epoch 15 Batch 3 Loss on real 0.061027724 loss on fake 0.067830704 generator loss 3.7656188
# Epoch 15 Batch 4 Loss on real 0.4604665 loss on fake 0.30388573 generator loss 5.385254
# Epoch 15 Batch 5 Loss on real 0.6048133 loss on fake 0.034398038 generator loss 3.1266425
# Epoch 15 Batch 6 Loss on real 0.050628603 loss on fake 0.24749422 generator loss 4.7271886
# Epoch 15 Batch 7 Loss on real 0.511627 loss on fake 0.043264925 generator loss 3.6908207
# Epoch 15 Batch 8 Loss on real 0.0014706041 loss on fake 0.055461835 generator loss 4.0808454
# Epoch 15 Batch 9 Loss on real 0.00047493985 loss on fake 0.024841623 generator loss 4.6380405
# Epoch 15 Batch 10 Loss on real 0.20154832 loss on fake 0.043605942 generator loss 3.6079812
# Epoch 15 Batch 11 Loss on real 0.118816875 loss on fake 0.14888562 generator loss 4.583557
# Epoch 16 Batch 0 Loss on real 0.34519735 loss on fake 0.07875938 generator loss 3.3005328
# Epoch 16 Batch 1 Loss on real 0.006595234 loss on fake 0.042020846 generator loss 4.3529286
# Epoch 16 Batch 2 Loss on real 1.0764436e-05 loss on fake 0.010594913 generator loss 4.899629
# Epoch 16 Batch 3 Loss on real 2.8766608e-06 loss on fake 0.010163348 generator loss 5.076381
# Epoch 16 Batch 4 Loss on real 0.002944201 loss on fake 0.006815585 generator loss 5.1889634
# Epoch 16 Batch 5 Loss on real 0.03582493 loss on fake 0.009366161 generator loss 4.939239
# Epoch 16 Batch 6 Loss on real 2.5934028e-07 loss on fake 0.008414266 generator loss 5.313169
# Epoch 16 Batch 7 Loss on real 0.26399076 loss on fake 0.012842655 generator loss 4.3659153
# Epoch 16 Batch 8 Loss on real 0.2176628 loss on fake 0.069321014 generator loss 3.6925068
# Epoch 16 Batch 9 Loss on real 2.9081738e-08 loss on fake 0.030171791 generator loss 4.61628
# Epoch 16 Batch 10 Loss on real 0.0001734523 loss on fake 0.016004777 generator loss 5.17106
# Epoch 16 Batch 11 Loss on real 0.043433245 loss on fake 0.012350328 generator loss 5.1618004
# Epoch 17 Batch 0 Loss on real 1.6607628e-06 loss on fake 0.009433828 generator loss 4.947222
# Epoch 17 Batch 1 Loss on real 1.7333831e-07 loss on fake 0.0073667974 generator loss 5.0239325
# Epoch 17 Batch 2 Loss on real 3.214297e-05 loss on fake 0.008046222 generator loss 5.5146394
# Epoch 17 Batch 3 Loss on real 7.049766e-07 loss on fake 0.00543661 generator loss 5.7846437
# Epoch 17 Batch 4 Loss on real 0.1450608 loss on fake 0.01841104 generator loss 4.1153436
# Epoch 17 Batch 5 Loss on real 0.0728543 loss on fake 0.064076684 generator loss 4.1053834
# Epoch 17 Batch 6 Loss on real 4.8538892e-05 loss on fake 0.01815445 generator loss 4.9725547
# Epoch 17 Batch 7 Loss on real 5.1772422e-05 loss on fake 0.00757687 generator loss 5.343649
# Epoch 17 Batch 8 Loss on real 7.238366e-07 loss on fake 0.0066608973 generator loss 5.501866
# Epoch 17 Batch 9 Loss on real 0.009845451 loss on fake 0.0076037683 generator loss 5.319663
# Epoch 17 Batch 10 Loss on real 1.2740212e-06 loss on fake 0.0065309084 generator loss 5.3568544
# Epoch 17 Batch 11 Loss on real 0.07851023 loss on fake 0.018556217 generator loss 4.364217
# Epoch 18 Batch 0 Loss on real 0.02302344 loss on fake 0.026601747 generator loss 4.0551
# Epoch 18 Batch 1 Loss on real 2.6881094e-07 loss on fake 0.06603942 generator loss 4.206537
# Epoch 18 Batch 2 Loss on real 1.8184679e-05 loss on fake 0.067551054 generator loss 4.893243
# Epoch 18 Batch 3 Loss on real 1.3773714e-05 loss on fake 0.11162422 generator loss 5.4002886
# Epoch 18 Batch 4 Loss on real 5.6452955e-06 loss on fake 0.14391954 generator loss 10.592771
# Epoch 18 Batch 5 Loss on real 1.2182969 loss on fake 0.26965997 generator loss 18.540842
# Epoch 18 Batch 6 Loss on real 0.14235388 loss on fake 6.333062e-08 generator loss 19.66247
# Epoch 18 Batch 7 Loss on real 0.32950887 loss on fake 0.0011891196 generator loss 6.8544855
# Epoch 18 Batch 8 Loss on real 5.653784e-05 loss on fake 0.24724178 generator loss 7.78807
# Epoch 18 Batch 9 Loss on real 0.053896517 loss on fake 0.019951705 generator loss 8.255149
# Epoch 18 Batch 10 Loss on real 0.2565262 loss on fake 0.5134387 generator loss 11.141889
# Epoch 18 Batch 11 Loss on real 0.95317465 loss on fake 0.05526043 generator loss 5.307584
# Epoch 19 Batch 0 Loss on real 0.1399826 loss on fake 0.4618597 generator loss 4.8548293
# Epoch 19 Batch 1 Loss on real 0.056101095 loss on fake 0.058434676 generator loss 5.5996203
# Epoch 19 Batch 2 Loss on real 0.18472941 loss on fake 0.041677658 generator loss 4.8793077
# Epoch 19 Batch 3 Loss on real 0.00013056085 loss on fake 0.10263354 generator loss 4.5112867
# Epoch 19 Batch 4 Loss on real 3.544994e-07 loss on fake 0.07813234 generator loss 6.2580066
# Epoch 19 Batch 5 Loss on real 0.36136487 loss on fake 0.017800482 generator loss 5.0180955
# Epoch 19 Batch 6 Loss on real 0.439088 loss on fake 0.24310277 generator loss 3.3531623
# Epoch 19 Batch 7 Loss on real 5.5217853e-09 loss on fake 0.15483056 generator loss 4.1889052
# Epoch 19 Batch 8 Loss on real 0.20559347 loss on fake 0.33063963 generator loss 4.13184
# Epoch 19 Batch 9 Loss on real 1.5584332 loss on fake 3.3893917 generator loss 4.188508
# Epoch 19 Batch 10 Loss on real 0.88907194 loss on fake 0.04511845 generator loss 3.5604336
# Epoch 19 Batch 11 Loss on real 0.40644696 loss on fake 0.1625514 generator loss 2.2217317
# Accuracy on real 0.8799999952316284 Accuracy on fake 1.0
# Epoch 20 Batch 0 Loss on real 0.20850235 loss on fake 0.21705085 generator loss 2.60117
# Epoch 20 Batch 1 Loss on real 0.09278392 loss on fake 0.17447107 generator loss 2.9496515
# Epoch 20 Batch 2 Loss on real 0.2739596 loss on fake 0.12438927 generator loss 3.003744
# Epoch 20 Batch 3 Loss on real 0.0714038 loss on fake 0.116039746 generator loss 3.035537
# Epoch 20 Batch 4 Loss on real 0.057762593 loss on fake 0.14538671 generator loss 3.6140082
# Epoch 20 Batch 5 Loss on real 0.1023893 loss on fake 0.1218076 generator loss 4.4384212
# Epoch 20 Batch 6 Loss on real 0.41064262 loss on fake 0.10430566 generator loss 2.8538003
# Epoch 20 Batch 7 Loss on real 0.084349416 loss on fake 0.19352478 generator loss 3.812959
# Epoch 20 Batch 8 Loss on real 0.030059943 loss on fake 0.21138918 generator loss 4.870569
# Epoch 20 Batch 9 Loss on real 0.11232381 loss on fake 0.08483244 generator loss 5.503727
# Epoch 20 Batch 10 Loss on real 0.45719996 loss on fake 0.8398917 generator loss 13.444906
# Epoch 20 Batch 11 Loss on real 1.9570165 loss on fake 0.0010651861 generator loss 6.182793
# Epoch 21 Batch 0 Loss on real 0.5016916 loss on fake 0.049517836 generator loss 2.5110476
# Epoch 21 Batch 1 Loss on real 0.36603045 loss on fake 0.20701844 generator loss 2.0169816
# Epoch 21 Batch 2 Loss on real 0.11806804 loss on fake 0.34480914 generator loss 4.0562468
# Epoch 21 Batch 3 Loss on real 0.26975477 loss on fake 0.037256606 generator loss 4.278264
# Epoch 21 Batch 4 Loss on real 0.4505353 loss on fake 0.09650578 generator loss 2.204526
# Epoch 21 Batch 5 Loss on real 0.24581645 loss on fake 0.18260522 generator loss 2.1659892
# Epoch 21 Batch 6 Loss on real 0.2177072 loss on fake 0.20613979 generator loss 2.1936889
# Epoch 21 Batch 7 Loss on real 0.017118936 loss on fake 0.10334956 generator loss 2.6167777
# Epoch 21 Batch 8 Loss on real 0.14203243 loss on fake 0.10450312 generator loss 2.7001667
# Epoch 21 Batch 9 Loss on real 0.071270235 loss on fake 0.08452827 generator loss 2.8745334
# Epoch 21 Batch 10 Loss on real 0.0047557373 loss on fake 0.071367115 generator loss 3.2590833
# Epoch 21 Batch 11 Loss on real 9.7448436e-05 loss on fake 0.0540951 generator loss 3.35245
# Epoch 22 Batch 0 Loss on real 0.0068083717 loss on fake 0.0494319 generator loss 3.5196545
# Epoch 22 Batch 1 Loss on real 0.1994099 loss on fake 0.09498727 generator loss 2.902458
# Epoch 22 Batch 2 Loss on real 0.033308584 loss on fake 0.108844936 generator loss 2.7026227
# Epoch 22 Batch 3 Loss on real 0.008555493 loss on fake 0.09730661 generator loss 2.7784328
# Epoch 22 Batch 4 Loss on real 0.08664444 loss on fake 0.10787489 generator loss 2.5324745
# Epoch 22 Batch 5 Loss on real 0.042064797 loss on fake 0.114695586 generator loss 2.573059
# Epoch 22 Batch 6 Loss on real 1.1620032e-05 loss on fake 0.12227368 generator loss 2.7450135
# Epoch 22 Batch 7 Loss on real 0.17904742 loss on fake 0.113861084 generator loss 2.5860348
# Epoch 22 Batch 8 Loss on real 0.14536585 loss on fake 0.12970234 generator loss 2.3693423
# Epoch 22 Batch 9 Loss on real 5.965976e-06 loss on fake 0.09611422 generator loss 2.6510339
# Epoch 22 Batch 10 Loss on real 1.0359446e-05 loss on fake 0.08744779 generator loss 2.871412
# Epoch 22 Batch 11 Loss on real 1.7624969e-06 loss on fake 0.100229554 generator loss 3.3109107
# Epoch 23 Batch 0 Loss on real 0.0023121359 loss on fake 0.047960818 generator loss 3.6060278
# Epoch 23 Batch 1 Loss on real 3.6536494e-07 loss on fake 0.031318218 generator loss 3.5071478
# Epoch 23 Batch 2 Loss on real 0.0003298018 loss on fake 0.05487412 generator loss 3.939322
# Epoch 23 Batch 3 Loss on real 1.011487e-05 loss on fake 0.042871922 generator loss 3.7586956
# Epoch 23 Batch 4 Loss on real 4.8928937e-06 loss on fake 0.14181292 generator loss 3.3194458
# Epoch 23 Batch 5 Loss on real 0.012356385 loss on fake 0.9859361 generator loss 8.820759
# Epoch 23 Batch 6 Loss on real 2.060642 loss on fake 0.010121327 generator loss 3.158999
# Epoch 23 Batch 7 Loss on real 0.15710953 loss on fake 0.43987724 generator loss 2.242203
# Epoch 23 Batch 8 Loss on real 0.0026044922 loss on fake 0.11518347 generator loss 2.8693128
# Epoch 23 Batch 9 Loss on real 0.016531566 loss on fake 0.121744834 generator loss 2.9923508
# Epoch 23 Batch 10 Loss on real 0.121209376 loss on fake 0.28439996 generator loss 2.9598799
# Epoch 23 Batch 11 Loss on real 0.30120072 loss on fake 0.41120687 generator loss 4.196175
# Epoch 24 Batch 0 Loss on real 0.25880468 loss on fake 0.051148728 generator loss 4.4173565
# Epoch 24 Batch 1 Loss on real 0.32624897 loss on fake 0.036872122 generator loss 3.486532
# Epoch 24 Batch 2 Loss on real 0.00026286513 loss on fake 0.10900643 generator loss 5.020961
# Epoch 24 Batch 3 Loss on real 0.18876775 loss on fake 0.029445687 generator loss 4.295384
# Epoch 24 Batch 4 Loss on real 0.11278141 loss on fake 0.14286259 generator loss 4.3334274
# Epoch 24 Batch 5 Loss on real 0.32085577 loss on fake 0.07255632 generator loss 4.366682
# Epoch 24 Batch 6 Loss on real 0.00016887226 loss on fake 0.07130368 generator loss 4.274051
# Epoch 24 Batch 7 Loss on real 3.3287395e-06 loss on fake 0.094664626 generator loss 4.112795
# Epoch 24 Batch 8 Loss on real 0.31014904 loss on fake 0.08820864 generator loss 2.702481
# Epoch 24 Batch 9 Loss on real 0.0034200947 loss on fake 0.14588933 generator loss 3.7944593
# Epoch 24 Batch 10 Loss on real 0.02829425 loss on fake 0.025169676 generator loss 4.337267
# Epoch 24 Batch 11 Loss on real 0.51692736 loss on fake 0.085891634 generator loss 2.8899503
# Accuracy on real 1.0 Accuracy on fake 1.0
# Epoch 25 Batch 0 Loss on real 3.5232454e-06 loss on fake 0.11047286 generator loss 3.5229483
# Epoch 25 Batch 1 Loss on real 8.668591e-08 loss on fake 0.036769424 generator loss 4.587268
# Epoch 25 Batch 2 Loss on real 7.107399e-05 loss on fake 0.042247478 generator loss 4.413608
# Epoch 25 Batch 3 Loss on real 0.031042762 loss on fake 0.30163333 generator loss 7.3149633
# Epoch 25 Batch 4 Loss on real 0.2782717 loss on fake 0.20261495 generator loss 7.6259303
# Epoch 25 Batch 5 Loss on real 0.00074598123 loss on fake 0.006257996 generator loss 7.4151974
# Epoch 25 Batch 6 Loss on real 1.1492442 loss on fake 4.246708 generator loss 27.460154
# Epoch 25 Batch 7 Loss on real 6.6635365 loss on fake 0.00017688666 generator loss 7.8342714
# Epoch 25 Batch 8 Loss on real 1.0937312 loss on fake 0.007959302 generator loss 4.7295713
# Epoch 25 Batch 9 Loss on real 0.36459315 loss on fake 0.020220226 generator loss 3.288343
# Epoch 25 Batch 10 Loss on real 0.12753455 loss on fake 0.055672217 generator loss 3.09415
# Epoch 25 Batch 11 Loss on real 0.0016671928 loss on fake 0.054830432 generator loss 3.2448652
# Epoch 26 Batch 0 Loss on real 0.09700308 loss on fake 0.058318615 generator loss 3.1479995
# Epoch 26 Batch 1 Loss on real 0.03766855 loss on fake 0.041478623 generator loss 3.5636756
# Epoch 26 Batch 2 Loss on real 0.034931604 loss on fake 0.039006755 generator loss 3.6701896
# Epoch 26 Batch 3 Loss on real 0.42824098 loss on fake 0.08729106 generator loss 3.1717734
# Epoch 26 Batch 4 Loss on real 0.12263477 loss on fake 0.07522504 generator loss 2.9688277
# Epoch 26 Batch 5 Loss on real 0.48467365 loss on fake 0.12355154 generator loss 2.4303837
# Epoch 26 Batch 6 Loss on real 0.01399105 loss on fake 0.111981384 generator loss 2.5519392
# Epoch 26 Batch 7 Loss on real 0.27047127 loss on fake 0.10931847 generator loss 2.6746423
# Epoch 26 Batch 8 Loss on real 0.15500572 loss on fake 0.09465011 generator loss 2.7601666
# Epoch 26 Batch 9 Loss on real 0.26011372 loss on fake 0.11939413 generator loss 2.3664417
# Epoch 26 Batch 10 Loss on real 0.17495006 loss on fake 0.15258187 generator loss 2.2629137
# Epoch 26 Batch 11 Loss on real 0.19635808 loss on fake 0.2217384 generator loss 2.1944492
# Epoch 27 Batch 0 Loss on real 0.04020284 loss on fake 0.14554517 generator loss 2.712552
# Epoch 27 Batch 1 Loss on real 0.34163293 loss on fake 0.12908573 generator loss 2.395329
# Epoch 27 Batch 2 Loss on real 0.12290668 loss on fake 0.1428589 generator loss 2.3439004
# Epoch 27 Batch 3 Loss on real 0.22073156 loss on fake 0.121583275 generator loss 2.7195923
# Epoch 27 Batch 4 Loss on real 0.21296005 loss on fake 0.08894566 generator loss 2.8816254
# Epoch 27 Batch 5 Loss on real 0.16724288 loss on fake 0.1253313 generator loss 2.682118
# Epoch 27 Batch 6 Loss on real 0.09999666 loss on fake 0.10554429 generator loss 3.0682456
# Epoch 27 Batch 7 Loss on real 0.16534375 loss on fake 0.06229448 generator loss 2.930517
# Epoch 27 Batch 8 Loss on real 0.30228412 loss on fake 0.117306076 generator loss 2.7738678
# Epoch 27 Batch 9 Loss on real 0.09530425 loss on fake 0.08348346 generator loss 3.1258247
# Epoch 27 Batch 10 Loss on real 0.14022194 loss on fake 0.052993078 generator loss 2.9892054
# Epoch 27 Batch 11 Loss on real 0.16077965 loss on fake 0.05834411 generator loss 3.0415695
# Epoch 28 Batch 0 Loss on real 0.0033438439 loss on fake 0.04357626 generator loss 3.3747036
# Epoch 28 Batch 1 Loss on real 0.14661261 loss on fake 0.05562183 generator loss 3.3474572
# Epoch 28 Batch 2 Loss on real 0.0007147168 loss on fake 0.04578735 generator loss 3.9428802
# Epoch 28 Batch 3 Loss on real 0.63825953 loss on fake 0.2200989 generator loss 2.2929468
# Epoch 28 Batch 4 Loss on real 0.04773054 loss on fake 0.12603132 generator loss 3.176953
# Epoch 28 Batch 5 Loss on real 0.113230385 loss on fake 0.09005729 generator loss 3.747118
# Epoch 28 Batch 6 Loss on real 0.0002447895 loss on fake 0.036640137 generator loss 3.583233
# Epoch 28 Batch 7 Loss on real 1.1537245e-05 loss on fake 0.02393201 generator loss 4.126927
# Epoch 28 Batch 8 Loss on real 0.02151827 loss on fake 0.05215037 generator loss 3.9081483
# Epoch 28 Batch 9 Loss on real 0.3198463 loss on fake 0.06524063 generator loss 3.68018
# Epoch 28 Batch 10 Loss on real 0.01956466 loss on fake 0.034846555 generator loss 4.012056
# Epoch 28 Batch 11 Loss on real 0.008175152 loss on fake 0.022911772 generator loss 4.1694
# Epoch 29 Batch 0 Loss on real 0.003471793 loss on fake 0.015675554 generator loss 4.993291
# Epoch 29 Batch 1 Loss on real 0.54667026 loss on fake 0.022906398 generator loss 3.972239
# Epoch 29 Batch 2 Loss on real 0.0009920143 loss on fake 0.023874486 generator loss 4.3024797
# Epoch 29 Batch 3 Loss on real 0.4007062 loss on fake 0.06631807 generator loss 2.9992132
# Epoch 29 Batch 4 Loss on real 0.1752261 loss on fake 0.088498764 generator loss 3.0361805
# Epoch 29 Batch 5 Loss on real 0.25828275 loss on fake 0.09224549 generator loss 3.0254219
# Epoch 29 Batch 6 Loss on real 0.07981344 loss on fake 0.051015813 generator loss 3.5291553
# Epoch 29 Batch 7 Loss on real 1.3005931e-10 loss on fake 0.03015186 generator loss 4.1783714
# Epoch 29 Batch 8 Loss on real 0.0048926114 loss on fake 0.026699627 generator loss 4.500285
# Epoch 29 Batch 9 Loss on real 5.16544e-08 loss on fake 0.032977324 generator loss 4.2226753
# Epoch 29 Batch 10 Loss on real 0.0025631078 loss on fake 0.046184808 generator loss 3.8454065
# Epoch 29 Batch 11 Loss on real 0.14968254 loss on fake 0.37088332 generator loss 4.2184196
# Accuracy on real 0.9599999785423279 Accuracy on fake 0.8199999928474426
# Epoch 30 Batch 0 Loss on real 0.006903114 loss on fake 0.04041875 generator loss 4.634639
# Epoch 30 Batch 1 Loss on real 0.027679244 loss on fake 0.35685563 generator loss 7.0849953
# Epoch 30 Batch 2 Loss on real 0.0011895992 loss on fake 0.0012751824 generator loss 7.735561
# Epoch 30 Batch 3 Loss on real 0.076784015 loss on fake 0.12210772 generator loss 6.731955
# Epoch 30 Batch 4 Loss on real 0.31177768 loss on fake 2.8218215 generator loss 10.94887
# Epoch 30 Batch 5 Loss on real 4.8604836 loss on fake 0.14125344 generator loss 1.2511259
# Epoch 30 Batch 6 Loss on real 0.33437344 loss on fake 0.39688012 generator loss 1.2926538
# Epoch 30 Batch 7 Loss on real 0.12320929 loss on fake 0.30481508 generator loss 1.573148
# Epoch 30 Batch 8 Loss on real 0.062250867 loss on fake 0.2072159 generator loss 1.9243515
# Epoch 30 Batch 9 Loss on real 0.13407339 loss on fake 0.16061656 generator loss 2.0365396
# Epoch 30 Batch 10 Loss on real 0.12622792 loss on fake 0.14513555 generator loss 2.204921
# Epoch 30 Batch 11 Loss on real 0.03336493 loss on fake 0.13778941 generator loss 2.3581846
# Epoch 31 Batch 0 Loss on real 0.10427829 loss on fake 0.10961485 generator loss 2.5428088
# Epoch 31 Batch 1 Loss on real 0.090910755 loss on fake 0.090650044 generator loss 2.4186158
# Epoch 31 Batch 2 Loss on real 0.27876192 loss on fake 0.11843616 generator loss 2.2700758
# Epoch 31 Batch 3 Loss on real 0.20771833 loss on fake 0.21888256 generator loss 2.3100686
# Epoch 31 Batch 4 Loss on real 0.008401174 loss on fake 0.22300832 generator loss 2.4204874
# Epoch 31 Batch 5 Loss on real 0.073512234 loss on fake 0.25269127 generator loss 2.60963
# Epoch 31 Batch 6 Loss on real 0.03744093 loss on fake 0.22625774 generator loss 2.8204756
# Epoch 31 Batch 7 Loss on real 0.080352806 loss on fake 0.4517906 generator loss 3.7071197
# Epoch 31 Batch 8 Loss on real 1.1897705 loss on fake 0.13818765 generator loss 1.3108246
# Epoch 31 Batch 9 Loss on real 0.011022835 loss on fake 0.416082 generator loss 1.7255594
# Epoch 31 Batch 10 Loss on real 0.036321644 loss on fake 0.15644012 generator loss 2.8213477
# Epoch 31 Batch 11 Loss on real 0.058713377 loss on fake 0.11782295 generator loss 3.01715
# Epoch 32 Batch 0 Loss on real 0.061346214 loss on fake 0.070325546 generator loss 2.9462402
# Epoch 32 Batch 1 Loss on real 0.060213875 loss on fake 0.10730808 generator loss 3.2884493
# Epoch 32 Batch 2 Loss on real 0.4037504 loss on fake 0.16227446 generator loss 1.7935497
# Epoch 32 Batch 3 Loss on real 0.033036973 loss on fake 1.026896 generator loss 3.5746112
# Epoch 32 Batch 4 Loss on real 0.41958976 loss on fake 0.09801587 generator loss 3.564088
# Epoch 32 Batch 5 Loss on real 0.05753122 loss on fake 0.04201901 generator loss 3.6133292
# Epoch 32 Batch 6 Loss on real 0.3948984 loss on fake 0.32793453 generator loss 2.8509753
# Epoch 32 Batch 7 Loss on real 0.24395208 loss on fake 0.16383532 generator loss 2.4983473
# Epoch 32 Batch 8 Loss on real 0.39966705 loss on fake 0.33087787 generator loss 2.7257354
# Epoch 32 Batch 9 Loss on real 0.06787441 loss on fake 0.14115457 generator loss 2.8387856
# Epoch 32 Batch 10 Loss on real 0.23779847 loss on fake 0.25854835 generator loss 3.1291363
# Epoch 32 Batch 11 Loss on real 0.08205522 loss on fake 0.07275718 generator loss 3.362204
# Epoch 33 Batch 0 Loss on real 0.23256202 loss on fake 0.11035519 generator loss 2.5049827
# Epoch 33 Batch 1 Loss on real 0.11098992 loss on fake 0.16110945 generator loss 2.9580986
# Epoch 33 Batch 2 Loss on real 0.1286361 loss on fake 0.08511048 generator loss 3.9032335
# Epoch 33 Batch 3 Loss on real 0.12337139 loss on fake 0.07613642 generator loss 3.4005969
# Epoch 33 Batch 4 Loss on real 0.22859274 loss on fake 0.07427316 generator loss 3.4008508
# Epoch 33 Batch 5 Loss on real 0.01950189 loss on fake 0.23150647 generator loss 6.221546
# Epoch 33 Batch 6 Loss on real 0.66346455 loss on fake 0.04604653 generator loss 4.427481
# Epoch 33 Batch 7 Loss on real 0.115130685 loss on fake 0.08752362 generator loss 3.500772
# Epoch 33 Batch 8 Loss on real 0.06335131 loss on fake 0.15189052 generator loss 3.1808388
# Epoch 33 Batch 9 Loss on real 0.22645354 loss on fake 0.14714493 generator loss 3.4973953
# Epoch 33 Batch 10 Loss on real 0.26503447 loss on fake 0.18948472 generator loss 3.106575
# Epoch 33 Batch 11 Loss on real 0.20034333 loss on fake 0.16452017 generator loss 3.185007
# Epoch 34 Batch 0 Loss on real 0.029419517 loss on fake 0.074012704 generator loss 4.017336
# Epoch 34 Batch 1 Loss on real 0.14303948 loss on fake 0.09052566 generator loss 3.6120148
# Epoch 34 Batch 2 Loss on real 0.2099189 loss on fake 0.07537145 generator loss 2.4364583
# Epoch 34 Batch 3 Loss on real 0.000455188 loss on fake 0.114813246 generator loss 3.6441095
# Epoch 34 Batch 4 Loss on real 0.0033256635 loss on fake 0.06376511 generator loss 4.214185
# Epoch 34 Batch 5 Loss on real 0.43243095 loss on fake 0.22480302 generator loss 3.9338937
# Epoch 34 Batch 6 Loss on real 0.08280558 loss on fake 0.15025838 generator loss 4.3960414
# Epoch 34 Batch 7 Loss on real 0.023715934 loss on fake 1.0181514 generator loss 8.45491
# Epoch 34 Batch 8 Loss on real 1.5563749 loss on fake 1.6035217 generator loss 6.3592153
# Epoch 34 Batch 9 Loss on real 0.68780947 loss on fake 0.07735854 generator loss 2.019512
# Epoch 34 Batch 10 Loss on real 0.13256676 loss on fake 2.7303674 generator loss 7.1152883
# Epoch 34 Batch 11 Loss on real 1.0460523 loss on fake 0.008945634 generator loss 4.452589
# Accuracy on real 0.8999999761581421 Accuracy on fake 1.0
# Epoch 35 Batch 0 Loss on real 0.20191757 loss on fake 0.36251584 generator loss 3.9493823
# Epoch 35 Batch 1 Loss on real 0.43994293 loss on fake 0.43693462 generator loss 3.506996
# Epoch 35 Batch 2 Loss on real 0.40127763 loss on fake 0.2908096 generator loss 2.7932
# Epoch 35 Batch 3 Loss on real 0.32831421 loss on fake 0.30733672 generator loss 2.524867
# Epoch 35 Batch 4 Loss on real 0.745481 loss on fake 0.45132986 generator loss 2.5439148
# Epoch 35 Batch 5 Loss on real 0.14492351 loss on fake 0.18944956 generator loss 2.6219218
# Epoch 35 Batch 6 Loss on real 0.10503405 loss on fake 0.4913861 generator loss 2.85162
# Epoch 35 Batch 7 Loss on real 0.61588997 loss on fake 0.4335796 generator loss 2.107958
# Epoch 35 Batch 8 Loss on real 0.45716774 loss on fake 0.7065802 generator loss 3.2125525
# Epoch 35 Batch 9 Loss on real 0.3104833 loss on fake 0.052488547 generator loss 3.5997913
# Epoch 35 Batch 10 Loss on real 0.30158648 loss on fake 0.088301696 generator loss 2.9356854
# Epoch 35 Batch 11 Loss on real 0.054463234 loss on fake 0.18476965 generator loss 2.813598
# Epoch 36 Batch 0 Loss on real 0.13402733 loss on fake 0.3978673 generator loss 2.9658544
# Epoch 36 Batch 1 Loss on real 0.03616127 loss on fake 0.18532948 generator loss 2.9224634
# Epoch 36 Batch 2 Loss on real 0.4263831 loss on fake 0.5829759 generator loss 2.3425589
# Epoch 36 Batch 3 Loss on real 0.11181187 loss on fake 0.1959797 generator loss 2.858136
# Epoch 36 Batch 4 Loss on real 0.6208591 loss on fake 0.27469534 generator loss 2.0121088
# Epoch 36 Batch 5 Loss on real 0.033804916 loss on fake 0.21665293 generator loss 2.4457157
# Epoch 36 Batch 6 Loss on real 0.081186794 loss on fake 0.19816102 generator loss 3.0258338
# Epoch 36 Batch 7 Loss on real 0.03504413 loss on fake 0.08578924 generator loss 2.9934564
# Epoch 36 Batch 8 Loss on real 0.05417047 loss on fake 0.10718856 generator loss 3.1252604
# Epoch 36 Batch 9 Loss on real 0.1925772 loss on fake 0.27900687 generator loss 4.1897497
# Epoch 36 Batch 10 Loss on real 0.19323951 loss on fake 0.032146256 generator loss 3.8253055
# Epoch 36 Batch 11 Loss on real 0.4084301 loss on fake 0.9243404 generator loss 5.259476
# Epoch 37 Batch 0 Loss on real 0.57343215 loss on fake 0.013112995 generator loss 4.1252756
# Epoch 37 Batch 1 Loss on real 0.51472026 loss on fake 0.10849803 generator loss 2.2010136
# Epoch 37 Batch 2 Loss on real 0.07333594 loss on fake 0.20797391 generator loss 2.5082538
# Epoch 37 Batch 3 Loss on real 0.053184047 loss on fake 0.14871757 generator loss 3.0911508
# Epoch 37 Batch 4 Loss on real 0.009152796 loss on fake 0.043175057 generator loss 3.542066
# Epoch 37 Batch 5 Loss on real 0.0752207 loss on fake 0.05324893 generator loss 3.4206057
# Epoch 37 Batch 6 Loss on real 0.010280413 loss on fake 0.054123137 generator loss 3.4984608
# Epoch 37 Batch 7 Loss on real 0.059983935 loss on fake 0.0851429 generator loss 3.567699
# Epoch 37 Batch 8 Loss on real 0.10538448 loss on fake 0.11044065 generator loss 3.286098
# Epoch 37 Batch 9 Loss on real 0.049984593 loss on fake 0.10251456 generator loss 3.4721954
# Epoch 37 Batch 10 Loss on real 0.01095777 loss on fake 0.20211588 generator loss 3.4785633
# Epoch 37 Batch 11 Loss on real 0.23935433 loss on fake 0.33449742 generator loss 3.131875
# Epoch 38 Batch 0 Loss on real 0.094287224 loss on fake 0.27716538 generator loss 3.566729
# Epoch 38 Batch 1 Loss on real 0.22188973 loss on fake 0.29319298 generator loss 3.5813022
# Epoch 38 Batch 2 Loss on real 0.29248673 loss on fake 0.14153382 generator loss 3.7924519
# Epoch 38 Batch 3 Loss on real 0.5512865 loss on fake 0.28219107 generator loss 2.6768234
# Epoch 38 Batch 4 Loss on real 0.027913077 loss on fake 0.19152856 generator loss 3.4837909
# Epoch 38 Batch 5 Loss on real 0.28328767 loss on fake 1.0527781 generator loss 5.09384
# Epoch 38 Batch 6 Loss on real 0.6607072 loss on fake 0.86520314 generator loss 5.762492
# Epoch 38 Batch 7 Loss on real 1.4597813 loss on fake 0.21095778 generator loss 3.1235375
# Epoch 38 Batch 8 Loss on real 0.24780227 loss on fake 0.17224514 generator loss 2.4953904
# Epoch 38 Batch 9 Loss on real 0.32953578 loss on fake 0.09587443 generator loss 2.7788775
# Epoch 38 Batch 10 Loss on real 0.1352815 loss on fake 0.081759244 generator loss 2.5261564
# Epoch 38 Batch 11 Loss on real 0.5937906 loss on fake 0.17036621 generator loss 2.3302574
# Epoch 39 Batch 0 Loss on real 0.27230975 loss on fake 0.37366977 generator loss 3.1543646
# Epoch 39 Batch 1 Loss on real 0.18693395 loss on fake 0.18805714 generator loss 3.8138568
# Epoch 39 Batch 2 Loss on real 0.41186532 loss on fake 0.74106187 generator loss 3.3920221
# Epoch 39 Batch 3 Loss on real 0.7012022 loss on fake 0.22701001 generator loss 2.6602802
# Epoch 39 Batch 4 Loss on real 0.4467915 loss on fake 0.3605261 generator loss 1.5429081
# Epoch 39 Batch 5 Loss on real 0.21949796 loss on fake 0.69313955 generator loss 1.9323249
# Epoch 39 Batch 6 Loss on real 0.4324267 loss on fake 0.24488507 generator loss 2.7058098
# Epoch 39 Batch 7 Loss on real 0.054839123 loss on fake 0.11413678 generator loss 2.869912
# Epoch 39 Batch 8 Loss on real 0.2151478 loss on fake 0.10872555 generator loss 2.4186847
# Epoch 39 Batch 9 Loss on real 0.010280694 loss on fake 0.17833632 generator loss 2.479493
# Epoch 39 Batch 10 Loss on real 0.06772933 loss on fake 0.10488385 generator loss 2.7580366
# Epoch 39 Batch 11 Loss on real 0.15627426 loss on fake 0.18263651 generator loss 2.541369
# Accuracy on real 0.9599999785423279 Accuracy on fake 1.0
# Epoch 40 Batch 0 Loss on real 0.10990628 loss on fake 0.12167775 generator loss 2.8955188
# Epoch 40 Batch 1 Loss on real 0.053117704 loss on fake 0.07878888 generator loss 3.02571
# Epoch 40 Batch 2 Loss on real 0.049124505 loss on fake 0.08434721 generator loss 2.902561
# Epoch 40 Batch 3 Loss on real 0.21120758 loss on fake 0.099321544 generator loss 2.9474826
# Epoch 40 Batch 4 Loss on real 0.0094459215 loss on fake 0.10838237 generator loss 3.026244
# Epoch 40 Batch 5 Loss on real 0.038642634 loss on fake 0.104596265 generator loss 3.4808338
# Epoch 40 Batch 6 Loss on real 0.10863184 loss on fake 0.122920364 generator loss 3.3355389
# Epoch 40 Batch 7 Loss on real 0.013966184 loss on fake 0.08881465 generator loss 4.188384
# Epoch 40 Batch 8 Loss on real 0.24788167 loss on fake 0.21071571 generator loss 5.236829
# Epoch 40 Batch 9 Loss on real 0.11148498 loss on fake 0.112334244 generator loss 6.518563
# Epoch 40 Batch 10 Loss on real 0.3821396 loss on fake 0.12450675 generator loss 4.8053083
# Epoch 40 Batch 11 Loss on real 1.1036574 loss on fake 5.0018992 generator loss 4.557442
# Epoch 41 Batch 0 Loss on real 0.30504227 loss on fake 0.039482083 generator loss 4.328232
# Epoch 41 Batch 1 Loss on real 0.48037514 loss on fake 0.10539643 generator loss 2.4291244
# Epoch 41 Batch 2 Loss on real 0.036604237 loss on fake 0.38894895 generator loss 3.1321192
# Epoch 41 Batch 3 Loss on real 0.3167597 loss on fake 0.22611433 generator loss 3.5184417
# Epoch 41 Batch 4 Loss on real 0.25251234 loss on fake 0.22838409 generator loss 3.3557568
# Epoch 41 Batch 5 Loss on real 0.6892144 loss on fake 0.7516527 generator loss 3.231662
# Epoch 41 Batch 6 Loss on real 0.9351037 loss on fake 0.19401337 generator loss 2.9095416
# Epoch 41 Batch 7 Loss on real 0.42130032 loss on fake 0.38309216 generator loss 3.4016824
# Epoch 41 Batch 8 Loss on real 0.5764677 loss on fake 0.22848345 generator loss 3.0634625
# Epoch 41 Batch 9 Loss on real 0.36848855 loss on fake 0.14205524 generator loss 2.4930253
# Epoch 41 Batch 10 Loss on real 0.3350211 loss on fake 0.24663945 generator loss 2.3371422
# Epoch 41 Batch 11 Loss on real 0.13764141 loss on fake 0.31396428 generator loss 4.2262626
# Epoch 42 Batch 0 Loss on real 0.24829634 loss on fake 0.090557 generator loss 4.3072557
# Epoch 42 Batch 1 Loss on real 0.2358067 loss on fake 0.10567874 generator loss 2.439071
# Epoch 42 Batch 2 Loss on real 0.32180098 loss on fake 0.40485242 generator loss 2.705348
# Epoch 42 Batch 3 Loss on real 0.2585697 loss on fake 0.36373284 generator loss 3.164724
# Epoch 42 Batch 4 Loss on real 0.28492716 loss on fake 0.17052667 generator loss 3.1131115
# Epoch 42 Batch 5 Loss on real 0.16620801 loss on fake 0.13621877 generator loss 2.876439
# Epoch 42 Batch 6 Loss on real 0.08676664 loss on fake 0.33225855 generator loss 3.3332336
# Epoch 42 Batch 7 Loss on real 0.62239856 loss on fake 0.96450377 generator loss 2.3857608
# Epoch 42 Batch 8 Loss on real 0.5386649 loss on fake 0.37880722 generator loss 2.0367136
# Epoch 42 Batch 9 Loss on real 0.3414772 loss on fake 0.24410184 generator loss 2.0018625
# Epoch 42 Batch 10 Loss on real 0.22017218 loss on fake 0.6840636 generator loss 3.0669909
# Epoch 42 Batch 11 Loss on real 0.37901223 loss on fake 0.14875323 generator loss 2.5648735
# Epoch 43 Batch 0 Loss on real 0.19714223 loss on fake 0.7984884 generator loss 3.962583
# Epoch 43 Batch 1 Loss on real 0.60136265 loss on fake 0.3064427 generator loss 3.0564697
# Epoch 43 Batch 2 Loss on real 0.5144213 loss on fake 0.24166709 generator loss 1.9252397
# Epoch 43 Batch 3 Loss on real 0.23166192 loss on fake 0.70274997 generator loss 2.0594687
# Epoch 43 Batch 4 Loss on real 0.31609246 loss on fake 0.16291074 generator loss 2.854968
# Epoch 43 Batch 5 Loss on real 0.46020898 loss on fake 0.32052097 generator loss 2.606954
# ...
# Epoch 85 Batch 4 Loss on real 0.2701672 loss on fake 0.13757925 generator loss 3.4187746
# Epoch 85 Batch 5 Loss on real 0.027178809 loss on fake 0.08450326 generator loss 3.5456927
# Epoch 85 Batch 6 Loss on real 0.094152234 loss on fake 0.07709949 generator loss 4.5128336
# Epoch 85 Batch 7 Loss on real 0.011822949 loss on fake 1.2170404 generator loss 14.404149
# Epoch 85 Batch 8 Loss on real 3.4561145 loss on fake 0.58912915 generator loss 4.965741
# Epoch 85 Batch 9 Loss on real 0.077202715 loss on fake 0.018044908 generator loss 4.516649
# Epoch 85 Batch 10 Loss on real 0.007039729 loss on fake 0.12904577 generator loss 3.4589977
# Epoch 85 Batch 11 Loss on real 0.116535425 loss on fake 1.4864016 generator loss 5.0408325
# Epoch 86 Batch 0 Loss on real 0.3182067 loss on fake 0.14496672 generator loss 5.1910033
# Epoch 86 Batch 1 Loss on real 0.13006303 loss on fake 0.1266061 generator loss 3.820485
# Epoch 86 Batch 2 Loss on real 0.57247764 loss on fake 0.5117034 generator loss 3.3889916
# Epoch 86 Batch 3 Loss on real 0.30941758 loss on fake 1.040252 generator loss 7.191725
# Epoch 86 Batch 4 Loss on real 0.40664497 loss on fake 0.015271434 generator loss 4.687491
# Epoch 86 Batch 5 Loss on real 0.12482366 loss on fake 0.16942894 generator loss 2.3976755
# Epoch 86 Batch 6 Loss on real 0.18553813 loss on fake 0.33071846 generator loss 2.2876177
# Epoch 86 Batch 7 Loss on real 0.5420379 loss on fake 0.4373478 generator loss 2.135523
# Epoch 86 Batch 8 Loss on real 0.14541864 loss on fake 0.13256146 generator loss 3.017285
# Epoch 86 Batch 9 Loss on real 0.20206518 loss on fake 0.14135863 generator loss 2.835269
# Epoch 86 Batch 10 Loss on real 0.030697757 loss on fake 0.1256409 generator loss 3.1107306
# Epoch 86 Batch 11 Loss on real 0.15074654 loss on fake 0.13131246 generator loss 2.7876165
# Epoch 87 Batch 0 Loss on real 0.20314138 loss on fake 0.066766776 generator loss 2.5369115
# Epoch 87 Batch 1 Loss on real 0.040457487 loss on fake 0.33444962 generator loss 3.2526722
# Epoch 87 Batch 2 Loss on real 0.2340126 loss on fake 0.09312034 generator loss 4.0750537
# Epoch 87 Batch 3 Loss on real 0.09131482 loss on fake 0.093046725 generator loss 3.651026
# Epoch 87 Batch 4 Loss on real 0.052645516 loss on fake 0.08575768 generator loss 3.215634
# Epoch 87 Batch 5 Loss on real 0.34678695 loss on fake 0.53115386 generator loss 2.8950915
# Epoch 87 Batch 6 Loss on real 0.08662822 loss on fake 0.39262357 generator loss 4.4497595
# Epoch 87 Batch 7 Loss on real 0.2593069 loss on fake 0.039144717 generator loss 3.8162544
# Epoch 87 Batch 8 Loss on real 0.38820586 loss on fake 0.10708208 generator loss 2.857192
# Epoch 87 Batch 9 Loss on real 0.07003738 loss on fake 0.19146436 generator loss 3.0424447
# Epoch 87 Batch 10 Loss on real 0.18178932 loss on fake 0.124182194 generator loss 3.4075208
# Epoch 87 Batch 11 Loss on real 0.032519013 loss on fake 0.10028091 generator loss 3.6439698
# Epoch 88 Batch 0 Loss on real 0.20655227 loss on fake 0.13819516 generator loss 3.5825286
# Epoch 88 Batch 1 Loss on real 0.05172366 loss on fake 0.07007281 generator loss 4.1457934
# Epoch 88 Batch 2 Loss on real 0.20958334 loss on fake 0.05382791 generator loss 3.3800666
# Epoch 88 Batch 3 Loss on real 0.0130611425 loss on fake 0.07755848 generator loss 3.4172254
# Epoch 88 Batch 4 Loss on real 0.290158 loss on fake 0.17225651 generator loss 3.0846589
# Epoch 88 Batch 5 Loss on real 0.1772591 loss on fake 0.25364184 generator loss 3.8927279
# Epoch 88 Batch 6 Loss on real 0.019714395 loss on fake 0.030114956 generator loss 4.6357183
# Epoch 88 Batch 7 Loss on real 0.27160138 loss on fake 0.16627796 generator loss 3.6132867
# Epoch 88 Batch 8 Loss on real 0.10062736 loss on fake 0.12594782 generator loss 3.5484545
# Epoch 88 Batch 9 Loss on real 0.5531406 loss on fake 0.09760293 generator loss 3.7222745
# Epoch 88 Batch 10 Loss on real 0.22628284 loss on fake 0.2869759 generator loss 4.726142
# Epoch 88 Batch 11 Loss on real 0.10259589 loss on fake 0.041585427 generator loss 4.156715
# Epoch 89 Batch 0 Loss on real 0.03356094 loss on fake 0.16667555 generator loss 4.6523895
# Epoch 89 Batch 1 Loss on real 0.13103208 loss on fake 0.14253847 generator loss 4.6553826
# Epoch 89 Batch 2 Loss on real 0.031502213 loss on fake 0.06583378 generator loss 4.0073695
# Epoch 89 Batch 3 Loss on real 0.35124668 loss on fake 0.55334 generator loss 6.5570903
# Epoch 89 Batch 4 Loss on real 0.63889325 loss on fake 0.0066620386 generator loss 6.9444346
# Epoch 89 Batch 5 Loss on real 0.29467717 loss on fake 0.04105301 generator loss 4.6315355
# Epoch 89 Batch 6 Loss on real 0.0037616163 loss on fake 0.08771667 generator loss 4.1169186
# Epoch 89 Batch 7 Loss on real 0.2640985 loss on fake 0.10705367 generator loss 3.2133775
# Epoch 89 Batch 8 Loss on real 0.01185494 loss on fake 0.12434155 generator loss 3.812891
# Epoch 89 Batch 9 Loss on real 0.0814608 loss on fake 0.069656074 generator loss 3.85031
# Epoch 89 Batch 10 Loss on real 0.09312435 loss on fake 0.09801591 generator loss 3.818029
# Epoch 89 Batch 11 Loss on real 0.04496653 loss on fake 0.07002824 generator loss 3.9976707
# Accuracy on real 0.9800000190734863 Accuracy on fake 0.9800000190734863
# Epoch 90 Batch 0 Loss on real 0.021457104 loss on fake 0.15769604 generator loss 5.0824795
# Epoch 90 Batch 1 Loss on real 0.3351103 loss on fake 0.1785682 generator loss 4.0214086
# Epoch 90 Batch 2 Loss on real 0.043521035 loss on fake 0.10757931 generator loss 4.2250605
# Epoch 90 Batch 3 Loss on real 0.124125995 loss on fake 0.23458564 generator loss 5.1587768
# Epoch 90 Batch 4 Loss on real 0.3388591 loss on fake 0.19021946 generator loss 3.8462892
# Epoch 90 Batch 5 Loss on real 0.027650064 loss on fake 0.09321296 generator loss 4.1620445
# Epoch 90 Batch 6 Loss on real 0.106325634 loss on fake 0.17111486 generator loss 4.5315576
# Epoch 90 Batch 7 Loss on real 0.29586658 loss on fake 0.14184001 generator loss 4.1310663
# Epoch 90 Batch 8 Loss on real 0.09090901 loss on fake 0.063958995 generator loss 3.514193
# Epoch 90 Batch 9 Loss on real 0.0092918305 loss on fake 0.18044722 generator loss 4.835877
# Epoch 90 Batch 10 Loss on real 0.7827873 loss on fake 0.674264 generator loss 4.2693295
# Epoch 90 Batch 11 Loss on real 0.037636384 loss on fake 0.024362898 generator loss 5.322388
# Epoch 91 Batch 0 Loss on real 0.19027716 loss on fake 0.06839133 generator loss 4.201035
# Epoch 91 Batch 1 Loss on real 0.31303564 loss on fake 0.33174178 generator loss 4.8608384
# Epoch 91 Batch 2 Loss on real 0.22826241 loss on fake 0.036437046 generator loss 4.4183655
# Epoch 91 Batch 3 Loss on real 0.08891607 loss on fake 0.1333011 generator loss 4.31577
# Epoch 91 Batch 4 Loss on real 0.09678308 loss on fake 0.17198913 generator loss 6.8594666
# Epoch 91 Batch 5 Loss on real 0.55545026 loss on fake 0.09739233 generator loss 5.4926124
# Epoch 91 Batch 6 Loss on real 0.22027 loss on fake 0.049200326 generator loss 3.9728022
# Epoch 91 Batch 7 Loss on real 0.127311 loss on fake 0.717869 generator loss 9.450262
# Epoch 91 Batch 8 Loss on real 0.55085766 loss on fake 0.004884394 generator loss 6.448778
# Epoch 91 Batch 9 Loss on real 0.38332033 loss on fake 0.081870496 generator loss 3.3554196
# Epoch 91 Batch 10 Loss on real 0.09165496 loss on fake 0.43537334 generator loss 3.6747248
# Epoch 91 Batch 11 Loss on real 0.022517145 loss on fake 0.054168124 generator loss 5.0412126
# Epoch 92 Batch 0 Loss on real 0.14986734 loss on fake 0.16177553 generator loss 4.40258
# Epoch 92 Batch 1 Loss on real 0.17455137 loss on fake 0.038198117 generator loss 4.0312114
# Epoch 92 Batch 2 Loss on real 0.059805978 loss on fake 0.13336517 generator loss 3.3961804
# Epoch 92 Batch 3 Loss on real 0.1610251 loss on fake 0.05343604 generator loss 3.267616
# Epoch 92 Batch 4 Loss on real 0.10871663 loss on fake 0.9287874 generator loss 7.2682676
# Epoch 92 Batch 5 Loss on real 0.22415982 loss on fake 0.14780734 generator loss 7.245547
# Epoch 92 Batch 6 Loss on real 0.50544375 loss on fake 0.025934355 generator loss 3.5952063
# Epoch 92 Batch 7 Loss on real 0.12773292 loss on fake 0.29465818 generator loss 3.5508242
# Epoch 92 Batch 8 Loss on real 0.02803061 loss on fake 0.2674875 generator loss 4.902115
# Epoch 92 Batch 9 Loss on real 0.26332286 loss on fake 0.058331743 generator loss 3.6051092
# Epoch 92 Batch 10 Loss on real 0.13924329 loss on fake 0.22340865 generator loss 3.4788775
# Epoch 92 Batch 11 Loss on real 0.12119042 loss on fake 0.08876815 generator loss 3.767064
# Epoch 93 Batch 0 Loss on real 0.23936433 loss on fake 0.52803326 generator loss 5.4741173
# Epoch 93 Batch 1 Loss on real 0.7084486 loss on fake 0.08935664 generator loss 4.9823046
# Epoch 93 Batch 2 Loss on real 0.123199284 loss on fake 0.09612093 generator loss 4.408559
# Epoch 93 Batch 3 Loss on real 0.5583431 loss on fake 0.1931753 generator loss 3.3430822
# Epoch 93 Batch 4 Loss on real 0.028456798 loss on fake 0.20445 generator loss 4.039283
# Epoch 93 Batch 5 Loss on real 0.05732854 loss on fake 0.20504175 generator loss 5.4649463
# Epoch 93 Batch 6 Loss on real 0.14346485 loss on fake 0.11708734 generator loss 5.010636
# Epoch 93 Batch 7 Loss on real 0.04360759 loss on fake 0.1937632 generator loss 4.439257
# Epoch 93 Batch 8 Loss on real 0.06328477 loss on fake 0.26944065 generator loss 6.604717
# Epoch 93 Batch 9 Loss on real 0.63113016 loss on fake 0.66170734 generator loss 6.7715344
# Epoch 93 Batch 10 Loss on real 0.5557868 loss on fake 0.014019147 generator loss 4.9697204
# Epoch 93 Batch 11 Loss on real 0.04079402 loss on fake 0.37022936 generator loss 5.431052
# Epoch 94 Batch 0 Loss on real 0.022188386 loss on fake 0.025462285 generator loss 5.0104384
# Epoch 94 Batch 1 Loss on real 0.25828135 loss on fake 0.11492044 generator loss 3.49539
# Epoch 94 Batch 2 Loss on real 0.090409525 loss on fake 0.34038052 generator loss 5.5497212
# Epoch 94 Batch 3 Loss on real 0.1217953 loss on fake 0.04689434 generator loss 5.8307967
# Epoch 94 Batch 4 Loss on real 0.19829267 loss on fake 0.3736196 generator loss 7.66453
# Epoch 94 Batch 5 Loss on real 0.4653485 loss on fake 0.055010397 generator loss 4.6126547
# Epoch 94 Batch 6 Loss on real 0.082210675 loss on fake 1.1900817 generator loss 10.704479
# Epoch 94 Batch 7 Loss on real 0.958761 loss on fake 0.006366173 generator loss 6.3901353
# Epoch 94 Batch 8 Loss on real 0.41014123 loss on fake 0.14052387 generator loss 3.0975618
# Epoch 94 Batch 9 Loss on real 0.13548355 loss on fake 0.29191694 generator loss 2.493286
# Epoch 94 Batch 10 Loss on real 0.072528936 loss on fake 0.20984025 generator loss 4.026795
# Epoch 94 Batch 11 Loss on real 0.19631207 loss on fake 0.19105344 generator loss 4.358346
# Accuracy on real 0.9399999976158142 Accuracy on fake 1.0
# Epoch 95 Batch 0 Loss on real 0.29415795 loss on fake 0.23795117 generator loss 4.3763947
# Epoch 95 Batch 1 Loss on real 0.12787819 loss on fake 0.14643353 generator loss 4.832208
# Epoch 95 Batch 2 Loss on real 0.15155374 loss on fake 0.18824752 generator loss 5.0258403
# Epoch 95 Batch 3 Loss on real 0.083504796 loss on fake 0.046230566 generator loss 5.5129137
# Epoch 95 Batch 4 Loss on real 0.29568484 loss on fake 0.083756216 generator loss 3.8524923
# Epoch 95 Batch 5 Loss on real 0.061134208 loss on fake 0.43358767 generator loss 5.6764464
# Epoch 95 Batch 6 Loss on real 0.64617246 loss on fake 0.07803312 generator loss 2.8713715
# Epoch 95 Batch 7 Loss on real 0.019429224 loss on fake 0.6657987 generator loss 4.9581623
# Epoch 95 Batch 8 Loss on real 0.13302583 loss on fake 0.14461519 generator loss 5.0810933
# Epoch 95 Batch 9 Loss on real 0.5970297 loss on fake 0.051602274 generator loss 4.1103425
# Epoch 95 Batch 10 Loss on real 0.066937245 loss on fake 0.21298711 generator loss 5.3278923
# Epoch 95 Batch 11 Loss on real 0.061923306 loss on fake 0.07797334 generator loss 6.3713307
# Epoch 96 Batch 0 Loss on real 0.55083346 loss on fake 0.112401016 generator loss 4.0402374
# Epoch 96 Batch 1 Loss on real 0.042133603 loss on fake 0.46853694 generator loss 5.484508
# Epoch 96 Batch 2 Loss on real 0.13122419 loss on fake 0.07659402 generator loss 4.904292
# Epoch 96 Batch 3 Loss on real 0.51096994 loss on fake 0.1426494 generator loss 4.2430005
# Epoch 96 Batch 4 Loss on real 0.08300767 loss on fake 0.16213568 generator loss 4.2090826
# Epoch 96 Batch 5 Loss on real 0.0925305 loss on fake 0.051293522 generator loss 4.4833
# Epoch 96 Batch 6 Loss on real 0.6575689 loss on fake 0.38286304 generator loss 3.8388615
# Epoch 96 Batch 7 Loss on real 0.14559737 loss on fake 0.0887991 generator loss 4.7308564
# Epoch 96 Batch 8 Loss on real 0.02088058 loss on fake 0.14413679 generator loss 5.557643
# Epoch 96 Batch 9 Loss on real 0.299782 loss on fake 0.3479402 generator loss 6.703936
# Epoch 96 Batch 10 Loss on real 0.37346157 loss on fake 0.08639673 generator loss 5.286066
# Epoch 96 Batch 11 Loss on real 0.12756108 loss on fake 0.069343604 generator loss 3.910393
# Epoch 97 Batch 0 Loss on real 0.12954608 loss on fake 0.2890031 generator loss 4.9823856
# Epoch 97 Batch 1 Loss on real 0.39828017 loss on fake 0.048300177 generator loss 3.4868896
# Epoch 97 Batch 2 Loss on real 0.045321826 loss on fake 0.1595168 generator loss 3.1143
# Epoch 97 Batch 3 Loss on real 0.014162208 loss on fake 0.16827722 generator loss 4.0338407
# Epoch 97 Batch 4 Loss on real 0.13919638 loss on fake 0.03989772 generator loss 3.5189579
# Epoch 97 Batch 5 Loss on real 0.021616772 loss on fake 0.14006309 generator loss 4.057622
# Epoch 97 Batch 6 Loss on real 0.29215077 loss on fake 0.32074848 generator loss 4.936812
# Epoch 97 Batch 7 Loss on real 0.4067355 loss on fake 0.18775451 generator loss 4.3620934
# Epoch 97 Batch 8 Loss on real 0.23178466 loss on fake 0.53886145 generator loss 5.1545177
# Epoch 97 Batch 9 Loss on real 0.2933591 loss on fake 0.021431586 generator loss 4.34171
# Epoch 97 Batch 10 Loss on real 0.07796366 loss on fake 0.24317674 generator loss 5.51162
# Epoch 97 Batch 11 Loss on real 0.16926682 loss on fake 0.041129824 generator loss 5.290192
# Epoch 98 Batch 0 Loss on real 0.176202 loss on fake 0.06876744 generator loss 3.9723597
# Epoch 98 Batch 1 Loss on real 0.04634832 loss on fake 0.17541681 generator loss 7.406809
# Epoch 98 Batch 2 Loss on real 0.42783973 loss on fake 0.039300993 generator loss 5.489722
# Epoch 98 Batch 3 Loss on real 0.053817634 loss on fake 0.3975903 generator loss 5.734181
# Epoch 98 Batch 4 Loss on real 0.1102614 loss on fake 0.015385863 generator loss 5.8002195
# Epoch 98 Batch 5 Loss on real 0.240296 loss on fake 0.04303913 generator loss 4.0027466
# Epoch 98 Batch 6 Loss on real 0.016527666 loss on fake 0.08959326 generator loss 3.7721941
# Epoch 98 Batch 7 Loss on real 0.01512029 loss on fake 0.076088004 generator loss 4.5211306
# Epoch 98 Batch 8 Loss on real 0.20972826 loss on fake 0.09655812 generator loss 3.6183221
# Epoch 98 Batch 9 Loss on real 0.064279154 loss on fake 0.1611724 generator loss 4.1729107
# Epoch 98 Batch 10 Loss on real 0.091794066 loss on fake 0.108667284 generator loss 5.0577683
# Epoch 98 Batch 11 Loss on real 0.3859096 loss on fake 0.12165216 generator loss 3.912726
# Epoch 99 Batch 0 Loss on real 0.036024667 loss on fake 0.48941055 generator loss 8.010355
# Epoch 99 Batch 1 Loss on real 0.97119236 loss on fake 0.1013295 generator loss 5.1936817
# Epoch 99 Batch 2 Loss on real 0.14393903 loss on fake 1.7102623 generator loss 8.023647
# Epoch 99 Batch 3 Loss on real 0.18838525 loss on fake 0.45347238 generator loss 8.820604
# Epoch 99 Batch 4 Loss on real 1.4627647 loss on fake 0.13152067 generator loss 2.729628
# Epoch 99 Batch 5 Loss on real 0.055067983 loss on fake 0.8090407 generator loss 4.4677954
# Epoch 99 Batch 6 Loss on real 0.17343183 loss on fake 0.065847665 generator loss 3.7258215
# Epoch 99 Batch 7 Loss on real 0.23946758 loss on fake 0.08925461 generator loss 3.1046264
# Epoch 99 Batch 8 Loss on real 0.025368124 loss on fake 0.087357484 generator loss 3.041963
# Epoch 99 Batch 9 Loss on real 0.087247245 loss on fake 0.35617018 generator loss 3.3369076
# Epoch 99 Batch 10 Loss on real 0.28960153 loss on fake 0.07328086 generator loss 3.4972613
# Epoch 99 Batch 11 Loss on real 0.07892008 loss on fake 0.111232154 generator loss 3.4670544
# Accuracy on real 0.9800000190734863 Accuracy on fake 1.0

# %%
latent_points = generate_latent_points(100,30)
x = generator.predict(latent_points)
x = (x+1) / 2.0
for i in range(5*5):
  plt.subplot(5,5,i+1)
  plt.axis("off")
  plt.imshow(x[i,:,:])
plt.show()
